# %%
import re
import pandas as pd
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
import spacy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/data_colab/CHLIZ_data.csv')
df
# Out:
#                          Datetime  ...         Username
# 0       2021-12-29 23:45:21+00:00  ...  CMarshallAlison
# 1       2021-12-29 23:23:45+00:00  ...      BuyHiSellLw
# 2       2021-12-29 23:17:42+00:00  ...        alrawenet
# 3       2021-12-29 23:10:48+00:00  ...    Catlikethiefz
# 4       2021-12-29 22:47:38+00:00  ...   YavasYazanAdam
# ...                           ...  ...              ...
# 100288  2021-05-15 11:17:01+00:00  ...   sedatylmzz1980
# 100289  2021-05-15 11:16:37+00:00  ...  coin_kriptopara
# 100290  2021-05-15 11:15:33+00:00  ...           MimckM
# 100291  2021-05-15 11:14:58+00:00  ...        LcoinR3b3
# 100292  2021-05-15 11:14:38+00:00  ...     YTBaranOzcan
#
# [100293 rows x 4 columns]

# %%
df.describe()
# Out:
#                            Datetime   Tweet id                 Text Username
# count                        100293     100143               100001    99859
# unique                        99363     100004                97393    20164
# top     Via https://t.co/KvYvE7sVIT  topstonks  @TommyBeFamous #CHZ  torshis
# freq                            133        135                  155     3331

# %%
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
for i in range (len(df)):
  df.iloc[i,2] = str(df.iloc[i,2])
df
# Out:
#                          Datetime  ...         Username
# 0       2021-12-29 23:45:21+00:00  ...  CMarshallAlison
# 1       2021-12-29 23:23:45+00:00  ...      BuyHiSellLw
# 2       2021-12-29 23:17:42+00:00  ...        alrawenet
# 3       2021-12-29 23:10:48+00:00  ...    Catlikethiefz
# 4       2021-12-29 22:47:38+00:00  ...   YavasYazanAdam
# ...                           ...  ...              ...
# 100288  2021-05-15 11:17:01+00:00  ...   sedatylmzz1980
# 100289  2021-05-15 11:16:37+00:00  ...  coin_kriptopara
# 100290  2021-05-15 11:15:33+00:00  ...           MimckM
# 100291  2021-05-15 11:14:58+00:00  ...        LcoinR3b3
# 100292  2021-05-15 11:14:38+00:00  ...     YTBaranOzcan
#
# [100293 rows x 4 columns]

# %%
df['new_Text'] = df['Text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['new_Text'].head()
# Out:
# 0    results of 15m calls ;) #c98 #dash #yfi #zec #...
# 1    @cryptoa40672341 #chz $spell $ach you’re welco...
# 2    اليوم الثالث على التوالي تهبط القيمة السوقية ل...
# 3    maybe not today, maybe not tomorrow, but somed...
# 4    i̇lk görsel #chz ikinci görsel #1inch https://...
# Name: new_Text, dtype: object

# %%
df['new_Text'] = df['new_Text'].str.replace('[^\w\s]','')
df['new_Text'].head()
# Out:
# 0    result 15 m call c98 dash yfi zec rvn audio su...
# 1        cryptoa40672341 chz spell ach PRON be welcome
# 2    اليوم الثالث على التوالي تهبط القيمة السوقية ل...
# 3    maybe today maybe tomorrow someday rest life c...
# 4    ilk görsel chz ikinci görsel 1inch httpstco1sg...
# Name: new_Text, dtype: object

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# def remove_emoji(text):
#     emoji_pattern = re.compile("["
#                            u"\U0001F600-\U0001F64F"  # emoticons
#                            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
#                            u"\U0001F680-\U0001F6FF"  # transport & map symbols
#                            u"\U0001F1E0-\U0001F1FF"  # flags
#                            u"\U00002702-\U000027B0"
#                            u"\U000024C2-\U0001F251"
#                            "]+", flags=re.UNICODE)
#     return emoji_pattern.sub(r'', text)
# df['new_Text'] = df['new_Text'].apply(lambda x: remove_emoji(x))

# %%
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags 
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)
df['new_Text'] = df['new_Text'].apply(lambda x: remove_emoji(x))

# %%
stop = stopwords.words('english')
df['new_Text'] = df['new_Text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df.head(20)
# Out:
#                      Datetime  ...                                           new_Text
# 0   2021-12-29 23:45:21+00:00  ...  result 15 call c98 dash yfi zec rvn audio sush...
# 1   2021-12-29 23:23:45+00:00  ...         cryptoa40672341 chz spell ach PRON welcome
# 2   2021-12-29 23:17:42+00:00  ...  اليوم الثالث على التوالي تهبط القيمة السوقية ل...
# 3   2021-12-29 23:10:48+00:00  ...  maybe today maybe tomorrow someday rest life c...
# 4   2021-12-29 22:47:38+00:00  ...  ilk görsel chz ikinci görsel 1inch httpstco1sg...
# 5   2021-12-29 21:57:24+00:00  ...  would rather crypto xrp ada vet hbar chz btc e...
# 6   2021-12-29 21:55:49+00:00  ...  عملات خاطري اشتريها بس احتاج احد يطمني avax cr...
# 7   2021-12-29 21:18:00+00:00  ...  chz chiliz chzusdt coin sahipleri almayı düşün...
# 8   2021-12-29 21:10:17+00:00  ...                              socio fail system chz
# 9   2021-12-29 21:05:48+00:00  ...  2316 profit chzusd target buy chzusd 02762 les...
# 10  2021-12-29 21:05:24+00:00  ...  price alert last 24h price chz fall 515 change...
# 11  2021-12-29 20:52:37+00:00  ...                                      bonker507 chz
# 12  2021-12-29 20:48:13+00:00  ...  chz adi chz adi alex adi socies yavşaklar ne y...
# 13  2021-12-29 20:07:59+00:00  ...  daily market analyzing chzusdt go last 24 hour...
# 14  2021-12-29 20:02:06+00:00  ...                            chz وبعدين مع الاستهبال
# 15  2021-12-29 19:49:35+00:00  ...  id10 PRON would mv24bwa4 httpstcozsntthjhh0 PR...
# 16  2021-12-29 19:49:11+00:00  ...                   yalniz_kurt5050 chz sxp avax uni
# 17  2021-12-29 19:47:04+00:00  ...  045 e kadar çıktı ancak 1 doların altında satm...
# 18  2021-12-29 19:34:17+00:00  ...  tepe revize edildi3 chz chzusdt chz2 httpstcod...
# 19  2021-12-29 19:22:59+00:00  ...  hello crypto trader please aware project big c...
#
# [20 rows x 5 columns]

# %%
def space(comment):
    doc = nlp(comment)
    return " ".join([token.lemma_ for token in doc])
df['new_Text']= df['new_Text'].apply(space)
df.head(20)
# Out:
#                      Datetime  ...                                           new_Text
# 0   2021-12-29 23:45:21+00:00  ...  result 15 call c98 dash yfi zec rvn audio sush...
# 1   2021-12-29 23:23:45+00:00  ...         cryptoa40672341 chz spell ach PRON welcome
# 2   2021-12-29 23:17:42+00:00  ...  اليوم الثالث على التوالي تهبط القيمة السوقية ل...
# 3   2021-12-29 23:10:48+00:00  ...  maybe today maybe tomorrow someday rest life c...
# 4   2021-12-29 22:47:38+00:00  ...  ilk görsel chz ikinci görsel 1inch httpstco1sg...
# 5   2021-12-29 21:57:24+00:00  ...  would rather crypto xrp ada vet hbar chz btc e...
# 6   2021-12-29 21:55:49+00:00  ...  عملات خاطري اشتريها بس احتاج احد يطمني avax cr...
# 7   2021-12-29 21:18:00+00:00  ...  chz chiliz chzusdt coin sahipleri almayı düşün...
# 8   2021-12-29 21:10:17+00:00  ...                              socio fail system chz
# 9   2021-12-29 21:05:48+00:00  ...  2316 profit chzusd target buy chzusd 02762 les...
# 10  2021-12-29 21:05:24+00:00  ...  price alert last 24h price chz fall 515 change...
# 11  2021-12-29 20:52:37+00:00  ...                                      bonker507 chz
# 12  2021-12-29 20:48:13+00:00  ...  chz adi chz adi alex adi socies yavşaklar ne y...
# 13  2021-12-29 20:07:59+00:00  ...  daily market analyzing chzusdt go last 24 hour...
# 14  2021-12-29 20:02:06+00:00  ...                            chz وبعدين مع الاستهبال
# 15  2021-12-29 19:49:35+00:00  ...  id10 PRON would mv24bwa4 httpstcozsntthjhh0 PR...
# 16  2021-12-29 19:49:11+00:00  ...                   yalniz_kurt5050 chz sxp avax uni
# 17  2021-12-29 19:47:04+00:00  ...  045 e kadar çıktı ancak 1 doların altında satm...
# 18  2021-12-29 19:34:17+00:00  ...  tepe revize edildi3 chz chzusdt chz2 httpstcod...
# 19  2021-12-29 19:22:59+00:00  ...  hello crypto trader please aware project big c...
#
# [20 rows x 5 columns]

# %%
df.describe()
# Out:
#                            Datetime   Tweet id    Text Username new_Text
# count                        100293     100143  100293    99859   100293
# unique                        99363     100004   97394    20164    95363
# top     Via https://t.co/KvYvE7sVIT  topstonks     nan  torshis      chz
# freq                            133        135     292     3331      526

# %%
datas = []
for i in range(len(df)):
    para = []
    para.append('CHLIZ')
    para.append(df.iloc[i,0])
    para.append(df.iloc[i,4])
    datas.append(para)

# %%
vader = SentimentIntensityAnalyzer()

# %%
columns = ['ticker','date', 'tweets']

# %%
CHLIZ_df = pd.DataFrame(datas, columns=columns)
CHLIZ_df['tweets']
# Out:
# 0         result 15 m call c98 dash yfi zec rvn audio su...
# 1           cryptoa40672341 chz spell ach -PRON- be welcome
# 2         اليوم الثالث على التوالي تهبط القيمة السوقية ل...
# 3         maybe today maybe tomorrow someday rest life c...
# 4         ilk görsel chz ikinci görsel 1inch httpstco1sg...
#                                 ...
# 100288           ytbaranozcan alex_dreyfus chz alex_dreyfus
# 100289                        chz chiliz httpstcoosmlyptsiv
# 100290    alex_dreyfus chiliz socio add new fan token ef...
# 100291    wtf vanaf het begin heb je chz je wallet zitte...
# 100292    project would not tell much ceo chz still do n...
# Name: tweets, Length: 100293, dtype: object

# %%
# Iterate through the headlines and get the polarity scores using vader
scores = CHLIZ_df['tweets'].apply(vader.polarity_scores).tolist()

# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
CHLIZ_df = CHLIZ_df.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
CHLIZ_df['date'] = pd.to_datetime(CHLIZ_df.date).dt.date

# %%
RCL_polarity_real.head()
# Out:
#   ticker        date  ...    pos  compound
# 0    RCL  2021-11-09  ...  0.000    0.0000
# 1    RCL  2021-11-09  ...  0.093   -0.6908
# 2    RCL  2021-11-09  ...  0.096   -0.0516
# 3    RCL  2021-11-09  ...  0.060   -0.7579
# 4    RCL  2021-11-09  ...  0.544    0.9709
#
# [5 rows x 7 columns]

# %%
plt.rcParams['figure.figsize'] = [20, 6]

# Group by date and ticker columns from scored_news and calculate the mean
mean_scores = RCL_polarity_real.groupby(['ticker','date']).mean()

# Unstack the column ticker
mean_scores = mean_scores.unstack()

# Get the cross-section of compound in the 'columns' axis
mean_scores = mean_scores.xs('compound', axis="columns").transpose()
mean_scores.head()
# Plot a bar chart with pandas
#mean_scores.plot(kind = 'bar')
#plt.grid()
# Out:
# ticker           RCL
# date
# 2020-03-09  0.145025
# 2020-03-10  0.174416
# 2020-03-11  0.207349
# 2020-03-12  0.192279
# 2020-03-13  0.119884

# %%
RCL_polarity_real.to_csv("RCL_polarity_real.csv", mode='w')
